# %%
# Package Imports
import os
import requests
import json
import pandas as pd
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
# Create Variable for Odds APi Key
odds_api_key = os.getenv("ODDS_API")

type(odds_api_key)
# Out:
# str

# %%
# This response variable returns all current active sports and their related keys.
# Use if you need to see all potential sports to pick odds from or if you need to find your sports key.
# Does not cost API usage quota.

# Create the response variable
sports_response = requests.get(f"https://api.the-odds-api.com/v4/sports/?apiKey={odds_api_key}").json()

# Print the results
print(json.dumps(sports_response, indent=4, sort_keys=True))

''' "active": true,
        "description": "US Football",
        "group": "American Football",
        "has_outrights": false,
        "key": "americanfootball_nfl",
        "title": "NFL"'''
# Out:
# [
#     {
#         "active": true,
#         "description": "US Football",
#         "group": "American Football",
#         "has_outrights": false,
#         "key": "americanfootball_nfl",
#         "title": "NFL"
#     },
#     {
#         "active": true,
#         "description": "Aussie Football",
#         "group": "Aussie Rules",
#         "has_outrights": false,
#         "key": "aussierules_afl",
#         "title": "AFL"
#     },
#     {
#         "active": true,
#         "description": "World Series Winner 2022",
#         "group": "Baseball",
#         "has_outrights": true,
#         "key": "baseball_mlb_world_series_winner",
#         "title": "MLB World Series Winner"
#     },
#     {
#         "active": true,
#         "description": "Basketball Euroleague",
#         "group": "Basketball",
#         "has_outrights": false,
#         "key": "basketball_euroleague",
#         "title": "Basketball Euroleague"
#     },
#     {
#         "active": true,
#         "description": "US Basketball",
#         "group": "Basketball",
#         "has_outrights": false,
#         "key": "basketball_nba",
#         "title": "NBA"
#     },
#     {
#         "active": true,
#         "description": "Championship Winner 2021/2022",
#         "group": "Basketball",
#         "has_outrights": true,
#         "key": "basketball_nba_championship_winner",
#         "title": "NBA Championship Winner"
#     },
#     {
#         "active": true,
#         "description": "US College Basketball",
#         "group": "Basketball",
#         "has_outrights": false,
#         "key": "basketball_ncaab",
#         "title": "NCAAB"
#     },
#     {
#         "active": true,
#         "description": "One Day Internationals",
#         "group": "Cricket",
#         "has_outrights": false,
#         "key": "cricket_odi",
#         "title": "One Day Internationals"
#     },
#     {
#         "active": true,
#         "description": "International Test Matches",
#         "group": "Cricket",
#         "has_outrights": false,
#         "key": "cricket_test_match",
#         "title": "Test Matches"
#     },
#     {
#         "active": true,
#         "description": "2022 Winner",
#         "group": "Golf",
#         "has_outrights": true,
#         "key": "golf_masters_tournament_winner",
#         "title": "Masters Tournament Winner"
#     },
#     {
#         "active": true,
#         "description": "2022 Winner",
#         "group": "Golf",
#         "has_outrights": true,
#         "key": "golf_pga_championship_winner",
#         "title": "PGA Championship Winner"
#     },
#     {
#         "active": true,
#         "description": "2022 Winner",
#         "group": "Golf",
#         "has_outrights": true,
#         "key": "golf_the_open_championship_winner",
#         "title": "The Open Winner"
#     },
#     {
#         "active": true,
#         "description": "2022 Winner",
#         "group": "Golf",
#         "has_outrights": true,
#         "key": "golf_us_open_winner",
#         "title": "US Open Winner"
#     },
#     {
#         "active": true,
#         "description": "US Ice Hockey",
#         "group": "Ice Hockey",
#         "has_outrights": false,
#         "key": "icehockey_nhl",
#         "title": "NHL"
#     },
#     {
#         "active": true,
#         "description": "Stanley Cup Winner 2021/2022",
#         "group": "Ice Hockey",
#         "has_outrights": true,
#         "key": "icehockey_nhl_championship_winner",
#         "title": "NHL Championship Winner"
#     },
#     {
#         "active": true,
#         "description": "Swedish Hockey Allsvenskan",
#         "group": "Ice Hockey",
#         "has_outrights": false,
#         "key": "icehockey_sweden_allsvenskan",
#         "title": "HockeyAllsvenskan"
#     },
#     {
#         "active": true,
#         "description": "Swedish Hockey League",
#         "group": "Ice Hockey",
#         "has_outrights": false,
#         "key": "icehockey_sweden_hockey_league",
#         "title": "SHL"
#     },
#     {
#         "active": true,
#         "description": "Mixed Martial Arts",
#         "group": "Mixed Martial Arts",
#         "has_outrights": false,
#         "key": "mma_mixed_martial_arts",
#         "title": "MMA"
#     },
#     {
#         "active": true,
#         "description": "Aussie Rugby League",
#         "group": "Rugby League",
#         "has_outrights": false,
#         "key": "rugbyleague_nrl",
#         "title": "NRL"
#     },
#     {
#         "active": true,
#         "description": "Africa Cup of Nations",
#         "group": "Soccer",
#         "has_outrights": false,
#         "key": "soccer_africa_cup_of_nations",
#         "title": "Africa Cup of Nations"
#     },
#     {
#         "active": true,
#         "description": "Aussie Soccer",
#         "group": "Soccer",
#         "has_outrights": false,
#         "key": "soccer_australia_aleague",
#         "title": "A-League"
#     },
#     {
#         "active": true,
#         "description": "Belgian First Division A",
#         "group": "Soccer",
#         "has_outrights": false,
#         "key": "soccer_belgium_first_div",
#         "title": "Belgium First Div"
#     },
#     {
#         "active": true,
#         "description": "",
#         "group": "Soccer",
#         "has_outrights": false,
#         "key": "soccer_denmark_superliga",
#         "title": "Denmark Superliga"
#     },
#     {
#         "active": true,
#         "description": "EFL Championship",
#         "group": "Soccer",
#         "has_outrights": false,
#         "key": "soccer_efl_champ",
#         "title": "Championship"
#     },
#     {
#         "active": true,
#         "description": "League Cup",
#         "group": "Soccer",
#         "has_outrights": false,
#         "key": "soccer_england_efl_cup",
#         "title": "EFL Cup"
#     },
#     {
#         "active": true,
#         "description": "EFL League 1",
#         "group": "Soccer",
#         "has_outrights": false,
#         "key": "soccer_england_league1",
#         "title": "League 1"
#     },
#     {
#         "active": true,
#         "description": "EFL League 2 ",
#         "group": "Soccer",
#         "has_outrights": false,
#         "key": "soccer_england_league2",
#         "title": "League 2"
#     },
#     {
#         "active": true,
#         "description": "English Premier League",
#         "group": "Soccer",
#         "has_outrights": false,
#         "key": "soccer_epl",
#         "title": "EPL"
#     },
#     {
#         "active": true,
#         "description": "Football Association Challenge Cup",
#         "group": "Soccer",
#         "has_outrights": false,
#         "key": "soccer_fa_cup",
#         "title": "FA Cup"
#     },
#     {
#         "active": true,
#         "description": "",
#         "group": "Soccer",
#         "has_outrights": false,
#         "key": "soccer_france_ligue_one",
#         "title": "Ligue 1 - France"
#     },
#     {
#         "active": true,
#         "description": "French Soccer",
#         "group": "Soccer",
#         "has_outrights": false,
#         "key": "soccer_france_ligue_two",
#         "title": "Ligue 2 - France"
#     },
#     {
#         "active": true,
#         "description": "German Soccer",
#         "group": "Soccer",
#         "has_outrights": false,
#         "key": "soccer_germany_bundesliga",
#         "title": "Bundesliga - Germany"
#     },
#     {
#         "active": true,
#         "description": "German Soccer",
#         "group": "Soccer",
#         "has_outrights": false,
#         "key": "soccer_germany_bundesliga2",
#         "title": "Bundesliga 2 - Germany"
#     },
#     {
#         "active": true,
#         "description": "Italian Soccer",
#         "group": "Soccer",
#         "has_outrights": false,
#         "key": "soccer_italy_serie_a",
#         "title": "Serie A - Italy"
#     },
#     {
#         "active": true,
#         "description": "Italian Soccer",
#         "group": "Soccer",
#         "has_outrights": false,
#         "key": "soccer_italy_serie_b",
#         "title": "Serie B - Italy"
#     },
#     {
#         "active": true,
#         "description": "Korean Soccer",
#         "group": "Soccer",
#         "has_outrights": false,
#         "key": "soccer_korea_kleague1",
#         "title": "K League 1"
#     },
#     {
#         "active": true,
#         "description": "Mexican Soccer",
#         "group": "Soccer",
#         "has_outrights": false,
#         "key": "soccer_mexico_ligamx",
#         "title": "Liga MX"
#     },
#     {
#         "active": true,
#         "description": "Dutch Soccer",
#         "group": "Soccer",
#         "has_outrights": false,
#         "key": "soccer_netherlands_eredivisie",
#         "title": "Dutch Eredivisie"
#     },
#     {
#         "active": true,
#         "description": "Portugese Soccer",
#         "group": "Soccer",
#         "has_outrights": false,
#         "key": "soccer_portugal_primeira_liga",
#         "title": "Primeira Liga - Portugal"
#     },
#     {
#         "active": true,
#         "description": "Russian Soccer",
#         "group": "Soccer",
#         "has_outrights": false,
#         "key": "soccer_russia_premier_league",
#         "title": "Premier League - Russia"
#     },
#     {
#         "active": true,
#         "description": "Spanish Soccer",
#         "group": "Soccer",
#         "has_outrights": false,
#         "key": "soccer_spain_la_liga",
#         "title": "La Liga - Spain"
#     },
#     {
#         "active": true,
#         "description": "Spanish Soccer",
#         "group": "Soccer",
#         "has_outrights": false,
#         "key": "soccer_spain_segunda_division",
#         "title": "La Liga 2 - Spain"
#     },
#     {
#         "active": true,
#         "description": "Scottish Premiership",
#         "group": "Soccer",
#         "has_outrights": false,
#         "key": "soccer_spl",
#         "title": "Premiership - Scotland"
#     },
#     {
#         "active": true,
#         "description": "Swedish Soccer",
#         "group": "Soccer",
#         "has_outrights": false,
#         "key": "soccer_sweden_allsvenskan",
#         "title": "Allsvenskan - Sweden"
#     },
#     {
#         "active": true,
#         "description": "Swedish Soccer",
#         "group": "Soccer",
#         "has_outrights": false,
#         "key": "soccer_sweden_superettan",
#         "title": "Superettan - Sweden"
#     },
#     {
#         "active": true,
#         "description": "Swiss Soccer",
#         "group": "Soccer",
#         "has_outrights": false,
#         "key": "soccer_switzerland_superleague",
#         "title": "Swiss Superleague"
#     },
#     {
#         "active": true,
#         "description": "Turkish Soccer",
#         "group": "Soccer",
#         "has_outrights": false,
#         "key": "soccer_turkey_super_league",
#         "title": "Turkey Super League"
#     },
#     {
#         "active": true,
#         "description": "European Champions League",
#         "group": "Soccer",
#         "has_outrights": false,
#         "key": "soccer_uefa_champs_league",
#         "title": "UEFA Champions"
#     },
#     {
#         "active": true,
#         "description": "European Europa League",
#         "group": "Soccer",
#         "has_outrights": false,
#         "key": "soccer_uefa_europa_league",
#         "title": "UEFA Europa"
#     },
#     {
#         "active": true,
#         "description": "Major League Soccer",
#         "group": "Soccer",
#         "has_outrights": false,
#         "key": "soccer_usa_mls",
#         "title": "MLS"
#     }
# ]
# ' "active": true,\n        "description": "US Football",\n        "group": "American Football",\n        "has_outrights": false,\n        "key": "americanfootball_nfl",\n        "title": "NFL"'

# %%
# Define variables for pull requests
SPORT = 'americanfootball_nfl' # use the sport_key from the /sports endpoint, or use 'upcoming' to see the next 8 games across all sports

REGIONS = 'us' # uk | us | eu | au. Multiple can be specified if comma delimited

MARKETS = 'h2h' # h2h | spreads | totals. Multiple can be specified if comma delimited

ODDS_FORMAT = 'american' # decimal | american

DATE_FORMAT = 'iso' # iso | unix

# %%
# This cell will process the API Call and create an odds_response variable to be printed below.
# This does count towards the API usage count.
odds_response = requests.get(f'https://api.the-odds-api.com/v4/sports/{SPORT}/odds', params={
    'api_key': odds_api_key,
    'regions': REGIONS,
    'markets': MARKETS,
    'oddsFormat': ODDS_FORMAT,
    'dateFormat': DATE_FORMAT,
})

# %%
# This cell prints the API call above.

if odds_response.status_code != 200:
    print(f'Failed to get odds: status_code {odds_response.status_code}, response body {odds_response.text}')

else:
    odds_json = odds_response.json()
    print('Number of events:', len(odds_json))
    print(json.dumps(odds_json, indent=4, sort_keys=True))

    # Check the usage quota
    print('Remaining requests', odds_response.headers['x-requests-remaining'])
    print('Used requests', odds_response.headers['x-requests-used'])
# Out:
# Number of events: 1
# [
#     {
#         "away_team": "Los Angeles Rams",
#         "bookmakers": [
#             {
#                 "key": "unibet",
#                 "last_update": "2022-02-01T01:45:20Z",
#                 "markets": [
#                     {
#                         "key": "h2h",
#                         "outcomes": [
#                             {
#                                 "name": "Cincinnati Bengals",
#                                 "price": 165
#                             },
#                             {
#                                 "name": "Los Angeles Rams",
#                                 "price": -189
#                             }
#                         ]
#                     }
#                 ],
#                 "title": "Unibet"
#             },
#             {
#                 "key": "barstool",
#                 "last_update": "2022-02-01T01:43:05Z",
#                 "markets": [
#                     {
#                         "key": "h2h",
#                         "outcomes": [
#                             {
#                                 "name": "Cincinnati Bengals",
#                                 "price": 160
#                             },
#                             {
#                                 "name": "Los Angeles Rams",
#                                 "price": -195
#                             }
#                         ]
#                     }
#                 ],
#                 "title": "Barstool Sportsbook"
#             },
#             {
#                 "key": "sugarhouse",
#                 "last_update": "2022-02-01T01:43:35Z",
#                 "markets": [
#                     {
#                         "key": "h2h",
#                         "outcomes": [
#                             {
#                                 "name": "Cincinnati Bengals",
#                                 "price": 165
#                             },
#                             {
#                                 "name": "Los Angeles Rams",
#                                 "price": -190
#                             }
#                         ]
#                     }
#                 ],
#                 "title": "SugarHouse"
#             },
#             {
#                 "key": "twinspires",
#                 "last_update": "2022-02-01T01:43:05Z",
#                 "markets": [
#                     {
#                         "key": "h2h",
#                         "outcomes": [
#                             {
#                                 "name": "Cincinnati Bengals",
#                                 "price": 160
#                             },
#                             {
#                                 "name": "Los Angeles Rams",
#                                 "price": -195
#                             }
#                         ]
#                     }
#                 ],
#                 "title": "TwinSpires"
#             },
#             {
#                 "key": "betmgm",
#                 "last_update": "2022-02-01T01:42:23Z",
#                 "markets": [
#                     {
#                         "key": "h2h",
#                         "outcomes": [
#                             {
#                                 "name": "Cincinnati Bengals",
#                                 "price": 165
#                             },
#                             {
#                                 "name": "Los Angeles Rams",
#                                 "price": -200
#                             }
#                         ]
#                     }
#                 ],
#                 "title": "BetMGM"
#             },
#             {
#                 "key": "fanduel",
#                 "last_update": "2022-02-01T01:46:42Z",
#                 "markets": [
#                     {
#                         "key": "h2h",
#                         "outcomes": [
#                             {
#                                 "name": "Cincinnati Bengals",
#                                 "price": 172
#                             },
#                             {
#                                 "name": "Los Angeles Rams",
#                                 "price": -205
#                             }
#                         ]
#                     }
#                 ],
#                 "title": "FanDuel"
#             },
#             {
#                 "key": "betus",
#                 "last_update": "2022-02-01T01:47:28Z",
#                 "markets": [
#                     {
#                         "key": "h2h",
#                         "outcomes": [
#                             {
#                                 "name": "Cincinnati Bengals",
#                                 "price": 165
#                             },
#                             {
#                                 "name": "Los Angeles Rams",
#                                 "price": -190
#                             }
#                         ]
#                     }
#                 ],
#                 "title": "BetUS"
#             },
#             {
#                 "key": "foxbet",
#                 "last_update": "2022-02-01T01:47:43Z",
#                 "markets": [
#                     {
#                         "key": "h2h",
#                         "outcomes": [
#                             {
#                                 "name": "Cincinnati Bengals",
#                                 "price": 160
#                             },
#                             {
#                                 "name": "Los Angeles Rams",
#                                 "price": -189
#                             }
#                         ]
#                     }
#                 ],
#                 "title": "FOX Bet"
#             },
#             {
#                 "key": "betrivers",
#                 "last_update": "2022-02-01T01:45:02Z",
#                 "markets": [
#                     {
#                         "key": "h2h",
#                         "outcomes": [
#                             {
#                                 "name": "Cincinnati Bengals",
#                                 "price": 165
#                             },
#                             {
#                                 "name": "Los Angeles Rams",
#                                 "price": -190
#                             }
#                         ]
#                     }
#                 ],
#                 "title": "BetRivers"
#             },
#             {
#                 "key": "pointsbetus",
#                 "last_update": "2022-02-01T01:44:24Z",
#                 "markets": [
#                     {
#                         "key": "h2h",
#                         "outcomes": [
#                             {
#                                 "name": "Cincinnati Bengals",
#                                 "price": 160
#                             },
#                             {
#                                 "name": "Los Angeles Rams",
#                                 "price": -191
#                             }
#                         ]
#                     }
#                 ],
#                 "title": "PointsBet (US)"
#             },
#             {
#                 "key": "mybookieag",
#                 "last_update": "2022-02-01T01:45:20Z",
#                 "markets": [
#                     {
#                         "key": "h2h",
#                         "outcomes": [
#                             {
#                                 "name": "Cincinnati Bengals",
#                                 "price": 150
#                             },
#                             {
#                                 "name": "Los Angeles Rams",
#                                 "price": -180
#                             }
#                         ]
#                     }
#                 ],
#                 "title": "MyBookie.ag"
#             },
#             {
#                 "key": "draftkings",
#                 "last_update": "2022-02-01T01:46:53Z",
#                 "markets": [
#                     {
#                         "key": "h2h",
#                         "outcomes": [
#                             {
#                                 "name": "Cincinnati Bengals",
#                                 "price": 165
#                             },
#                             {
#                                 "name": "Los Angeles Rams",
#                                 "price": -195
#                             }
#                         ]
#                     }
#                 ],
#                 "title": "DraftKings"
#             },
#             {
#                 "key": "betfair",
#                 "last_update": "2022-02-01T01:42:21Z",
#                 "markets": [
#                     {
#                         "key": "h2h",
#                         "outcomes": [
#                             {
#                                 "name": "Cincinnati Bengals",
#                                 "price": 174
#                             },
#                             {
#                                 "name": "Los Angeles Rams",
#                                 "price": -175
#                             }
#                         ]
#                     },
#                     {
#                         "key": "h2h_lay",
#                         "outcomes": [
#                             {
#                                 "name": "Cincinnati Bengals",
#                                 "price": 176
#                             },
#                             {
#                                 "name": "Los Angeles Rams",
#                                 "price": -172
#                             }
#                         ]
#                     }
#                 ],
#                 "title": "Betfair"
#             },
#             {
#                 "key": "williamhill_us",
#                 "last_update": "2022-02-01T01:47:04Z",
#                 "markets": [
#                     {
#                         "key": "h2h",
#                         "outcomes": [
#                             {
#                                 "name": "Cincinnati Bengals",
#                                 "price": 170
#                             },
#                             {
#                                 "name": "Los Angeles Rams",
#                                 "price": -200
#                             }
#                         ]
#                     }
#                 ],
#                 "title": "William Hill (US)"
#             },
#             {
#                 "key": "gtbets",
#                 "last_update": "2022-02-01T01:42:43Z",
#                 "markets": [
#                     {
#                         "key": "h2h",
#                         "outcomes": [
#                             {
#                                 "name": "Cincinnati Bengals",
#                                 "price": 175
#                             },
#                             {
#                                 "name": "Los Angeles Rams",
#                                 "price": -200
#                             }
#                         ]
#                     }
#                 ],
#                 "title": "GTbets"
#             },
#             {
#                 "key": "betonlineag",
#                 "last_update": "2022-02-01T01:46:01Z",
#                 "markets": [
#                     {
#                         "key": "h2h",
#                         "outcomes": [
#                             {
#                                 "name": "Cincinnati Bengals",
#                                 "price": 167
#                             },
#                             {
#                                 "name": "Los Angeles Rams",
#                                 "price": -192
#                             }
#                         ]
#                     }
#                 ],
#                 "title": "BetOnline.ag"
#             },
#             {
#                 "key": "lowvig",
#                 "last_update": "2022-02-01T01:41:52Z",
#                 "markets": [
#                     {
#                         "key": "h2h",
#                         "outcomes": [
#                             {
#                                 "name": "Cincinnati Bengals",
#                                 "price": 167
#                             },
#                             {
#                                 "name": "Los Angeles Rams",
#                                 "price": -192
#                             }
#                         ]
#                     }
#                 ],
#                 "title": "LowVig.ag"
#             },
#             {
#                 "key": "bovada",
#                 "last_update": "2022-02-01T01:45:34Z",
#                 "markets": [
#                     {
#                         "key": "h2h",
#                         "outcomes": [
#                             {
#                                 "name": "Cincinnati Bengals",
#                                 "price": 165
#                             },
#                             {
#                                 "name": "Los Angeles Rams",
#                                 "price": -195
#                             }
#                         ]
#                     }
#                 ],
#                 "title": "Bovada"
#             }
#         ],
#         "commence_time": "2022-02-13T23:30:00Z",
#         "home_team": "Cincinnati Bengals",
#         "id": "80b298784f288da163240b7e42ead601",
#         "sport_key": "americanfootball_nfl",
#         "sport_title": "NFL"
#     }
# ]
# Remaining requests 498
# Used requests 2

# %%
# Function to pull the weekly odds.
def weekly_odds(dump):
    odds_df = pd.DataFrame()
    for i in range(len(dump)):
        t1 = pd.DataFrame(dump[i]['bookmakers'][1]['markets'][0]['outcomes'][0], index=[0])
        t1 = t1.rename(columns={'name':'t1_name','price':'t1_odds'})
        t2 = pd.DataFrame(dump[i]['bookmakers'][1]['markets'][0]['outcomes'][1], index=[0])
        t2 = t2.rename(columns={'name':'t2_name','price':'t2_odds'}) 
        t1['away_team'] = dump[i]['away_team']
        t1['home_team'] = dump[i]['home_team']
        joined_odds = pd.concat([t1, t2], axis='columns')
        odds_df = odds_df.append(joined_odds)
         
    return odds_df

# %%
upcoming_games = weekly_odds(odds_json)
upcoming_games = upcoming_games.reset_index().drop(columns='index')
upcoming_games
# Out:
#               t1_name  t1_odds         away_team           home_team  \
# 0  Cincinnati Bengals      160  Los Angeles Rams  Cincinnati Bengals
#
#             t2_name  t2_odds
# 0  Los Angeles Rams     -195

# %%
first_column = upcoming_games.pop('away_team')
second_column = upcoming_games.pop('home_team')
upcoming_games.insert(0,'away_team',first_column)
upcoming_games.insert(1,'home_team',second_column)

upcoming_games
# Out:
#           away_team           home_team             t1_name  t1_odds  \
# 0  Los Angeles Rams  Cincinnati Bengals  Cincinnati Bengals      160
#
#             t2_name  t2_odds
# 0  Los Angeles Rams     -195

# %%
upcoming_games.to_csv("Resources/upcoming_games.csv")

# %%
Team_1 = f"{upcoming_games.iloc[0,2]} : {upcoming_games.iloc[0,3]}"
Team_2 = f"{upcoming_games.iloc[0,4]} : {upcoming_games.iloc[0,5]}"
display(Team_1)
display(Team_2)
# Out:
# 'Cincinnati Bengals : 160'
# 'Los Angeles Rams : -195'
